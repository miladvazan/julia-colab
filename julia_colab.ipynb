# %% [markdown]
# <a href="https://colab.research.google.com/github/miladvazan/julia-colab/blob/main/julia_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installation cell
%%shell
if ! command -v julia 3>&1 > /dev/null
then
    wget -q 'https://julialang-s3.julialang.org/bin/linux/x64/1.6/julia-1.6.0-linux-x86_64.tar.gz' \
        -O /tmp/julia.tar.gz
    tar -x -f /tmp/julia.tar.gz -C /usr/local --strip-components 1
    rm /tmp/julia.tar.gz
fi
julia -e 'using Pkg; pkg"add IJulia; precompile;"'
echo 'Done'
# Out:
# ┌ Warning: The Pkg REPL interface is intended for interactive use, use with caution from scripts.
# └ @ Pkg.REPLMode /buildworker/worker/package_linux64/build/usr/share/julia/stdlib/v1.6/Pkg/src/REPLMode/REPLMode.jl:378
#   Installing known registries into `~/.julia`
#        Added registry `General` to `~/.julia/registries/General`
#    Resolving package versions...
#    Installed VersionParsing ── v1.2.0
#    Installed Conda ─────────── v1.5.1
#    Installed libsodium_jll ─── v1.0.18+1
#    Installed SoftGlobalScope ─ v1.1.0
#    Installed JSON ──────────── v0.21.1
#    Installed JLLWrappers ───── v1.2.0
#    Installed Parsers ───────── v1.1.0
#    Installed IJulia ────────── v1.23.2
#    Installed ZMQ ───────────── v1.2.1
#    Installed ZeroMQ_jll ────── v4.3.2+6
#    Installed MbedTLS ───────── v1.0.3
# ...
#   Downloaded artifact: libsodium
# ...
#   Downloaded artifact: ZeroMQ
#     Updating `~/.julia/environments/v1.6/Project.toml`
#   [7073ff75] + IJulia v1.23.2
# ...

# %% [markdown]
# # After you run the first cell:
#
# ---

# %% [markdown]
#
#
# *   select **Edit** and select **Notebook settings**
# *    Select **Julia 1.6**
#
#
#
#
# ![Annotation 2021-03-27 114642.jpg](data:image/jpeg;base64,...)

# %%
VERSION
# Out:
# v"1.6.0"

# %%
println("hello world")
# Out:
# hello world
